# %% [markdown]
# <a href="https://colab.research.google.com/github/harshatejas/pytorch_custom_object_detection/blob/main/Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/farelptraalbana/klasifikasi-faster-rcnn.git
# Out:
# Cloning into 'klasifikasi-faster-rcnn'...
# remote: Enumerating objects: 397, done.
# remote: Counting objects: 100% (397/397), done.
# remote: Compressing objects: 100% (391/391), done.
# remote: Total 397 (delta 6), reused 396 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (397/397), 36.73 MiB | 15.39 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd /content/klasifikasi-faster-rcnn
# Out:
# /content/klasifikasi-faster-rcnn

# %%
# Imports
import os
import numpy as np
import pandas as pd
import cv2
import json

import torch
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

from engine import train_one_epoch, evaluate
import utils
import transforms as T

# %%
# Hyperparameters
test_set_length = 40 		 # Test set (number of images)
train_batch_size = 2  		 # Train batch size
test_batch_size = 1    		 # Test batch size
num_classes = 6        		 # Number of classes
learning_rate = 0.005  		 # Learning rate
num_epochs = 10      	     # Number of epochs
save_path = '/content/drive/My Drive/saved_models/model1'

# %%
# Helper functions
def create_labels_dict_and_txt(path_to_csv):
    data = pd.read_csv(path_to_csv)
    labels = data['class'].unique()
    labels_dict = {index: label for index, label in enumerate(labels)}

    # We need to create labels.txt and write labels dictionary into it
    with open('labels.txt', 'w') as f:
        json.dump(labels_dict, f)

    return labels_dict

# Jalankan fungsi dengan path_to_csv yang valid
path_to_csv = 'cards_dataset/train_labels.csv'
labels_dict = create_labels_dict_and_txt(path_to_csv)

# Tampilkan output dictionary
print(labels_dict)

def parse_one_annot(path, filename, labels_dict):

	data = pd.read_csv(path)

	class_names = data['class'].unique()
	classes_df = data[data["filename"] == filename]["class"]
	classes_array = classes_df.to_numpy()

	boxes_df = data[data["filename"] == filename][["xmin", "ymin", "xmax", "ymax"]]
	boxes_array = boxes_df.to_numpy()

	classes = []
	for key, value in labels_dict.items():
		for i in classes_array:
			if i == value:
				classes.append(key)

	# Convert list to tuple
	classes = tuple(classes)

	return boxes_array, classes

def get_model(num_classes):

	# Load an pre-trained object detectin model (in this case faster-rcnn)
	model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights='FasterRCNN_ResNet50_FPN_Weights.COCO_V1')

	# Number of input features
	in_features = model.roi_heads.box_predictor.cls_score.in_features

	# Replace the pre-trained head with a new head
	model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

	return model


def get_transforms(train):

	transforms = []

	# Convert numpy image to PyTorch Tensor
	transforms.append(T.ToTensor())

	if train:
		# Data augmentation
		transforms.append(T.RandomHorizontalFlip(0.5))

	return T.Compose(transforms)
# Out:
# {0: 'queen', 1: 'ten', 2: 'nine', 3: 'king', 4: 'jack', 5: 'ace'}

# %%
class CardsDataset(torch.utils.data.Dataset):

	""" The dataset contains images of playing cards
		The dataset includes images of king, queen, jack, ten, nine and ace playing cards"""

	def __init__(self, dataset_dir, csv_file, labels_dict, transforms = None):

		self.dataset_dir = dataset_dir
		self.csv_file = csv_file
		self.transforms = transforms
		self.labels_dict = labels_dict
		self.image_names = [file for file in sorted(os.listdir(os.path.join(dataset_dir))) if file.endswith('.jpg') or file.endswith('.JPG')]

	def __getitem__(self, index):

		image_path = os.path.join(self.dataset_dir, self.image_names[index])
		image = cv2.imread(image_path)
		# Convert BGR to RGB
		image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

		box_array, classes = parse_one_annot(self.csv_file, self.image_names[index], self.labels_dict)
		boxes = torch.as_tensor(box_array, dtype = torch.float32)

		labels = torch.tensor(classes, dtype=torch.int64)

		image_id = torch.tensor([index])
		area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

		iscrowd = torch.tensor(classes, dtype=torch.int64)
		target = {}
		target["boxes"] = boxes
		target["labels"] = labels
		target["image_id"] = image_id
		target["area"] = area
		target["iscrowd"] = iscrowd

		if self.transforms is not None:
			image, target = self.transforms(image, target)

		return image, target

	def __len__(self):

		return len(self.image_names)

# %%
# Setting up the device
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

labels_dict = create_labels_dict_and_txt("cards_dataset/train_labels.csv")

# Define train and test dataset
dataset = CardsDataset(dataset_dir = "cards_dataset/train/", csv_file = "cards_dataset/train_labels.csv",
                        labels_dict = labels_dict, transforms = get_transforms(train = True))

dataset_test = CardsDataset(dataset_dir = "cards_dataset/train/", csv_file = "cards_dataset/train_labels.csv",
                        labels_dict = labels_dict, transforms = get_transforms(train = False))

# Split the dataset into train and test
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()
dataset = torch.utils.data.Subset(dataset, indices[:-test_set_length])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-test_set_length:])

# Define train and test dataloaders
data_loader = torch.utils.data.DataLoader(dataset, batch_size = train_batch_size, shuffle = True,
                num_workers = 2, collate_fn = utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(dataset_test, batch_size = test_batch_size, shuffle = False,
                num_workers = 2, collate_fn = utils.collate_fn)

print(f"We have: {len(indices)} images in the dataset, {len(dataset)} are training images and {len(dataset_test)} are test images")
# Out:
# We have: 358 images in the dataset, 318 are training images and 40 are test images

# %%
# Get the model using helper function
model = get_model(num_classes)
model.to(device = device)

# Construct the optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr = learning_rate, momentum = 0.9, weight_decay = 0.0005)

# Learning rate scheduler decreases the learning rate by 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 3, gamma = 0.1)

for epoch in range(num_epochs):

    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq = 10)
    lr_scheduler.step()
    # Evaluate on the test dataset
    evaluate(model, data_loader_test, device = device)

# Simpan model ke Google Drive
torch.save(model.state_dict(), save_path)
# Out:
# Epoch: [0]  [  0/159]  eta: 0:01:49  lr: 0.000037  loss: 1.7574 (1.7574)  loss_classifier: 1.4179 (1.4179)  loss_box_reg: 0.3299 (0.3299)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0091 (0.0091)  time: 0.6900  data: 0.1322  max mem: 4767
# Epoch: [0]  [ 10/159]  eta: 0:01:29  lr: 0.000353  loss: 1.4010 (1.2994)  loss_classifier: 1.1647 (1.0576)  loss_box_reg: 0.2336 (0.2338)  loss_objectness: 0.0026 (0.0042)  loss_rpn_box_reg: 0.0024 (0.0038)  time: 0.6028  data: 0.0192  max mem: 6203
# Epoch: [0]  [ 20/159]  eta: 0:01:18  lr: 0.000669  loss: 0.7264 (0.9725)  loss_classifier: 0.5483 (0.7253)  loss_box_reg: 0.1917 (0.2386)  loss_objectness: 0.0026 (0.0052)  loss_rpn_box_reg: 0.0018 (0.0033)  time: 0.5588  data: 0.0099  max mem: 6203
# Epoch: [0]  [ 30/159]  eta: 0:01:13  lr: 0.000985  loss: 0.4746 (0.8183)  loss_classifier: 0.2498 (0.5736)  loss_box_reg: 0.2007 (0.2368)  loss_objectness: 0.0018 (0.0048)  loss_rpn_box_reg: 0.0018 (0.0031)  time: 0.5502  data: 0.0106  max mem: 6203
# Epoch: [0]  [ 40/159]  eta: 0:01:07  lr: 0.001301  loss: 0.4084 (0.7277)  loss_classifier: 0.1735 (0.4821)  loss_box_reg: 0.2107 (0.2379)  loss_objectness: 0.0018 (0.0047)  loss_rpn_box_reg: 0.0022 (0.0030)  time: 0.5659  data: 0.0093  max mem: 6203
# Epoch: [0]  [ 50/159]  eta: 0:01:02  lr: 0.001617  loss: 0.3701 (0.6756)  loss_classifier: 0.1591 (0.4251)  loss_box_reg: 0.2107 (0.2432)  loss_objectness: 0.0010 (0.0045)  loss_rpn_box_reg: 0.0023 (0.0029)  time: 0.5859  data: 0.0096  max mem: 6205
# Epoch: [0]  [ 60/159]  eta: 0:00:56  lr: 0.001933  loss: 0.3660 (0.6322)  loss_classifier: 0.1591 (0.3840)  loss_box_reg: 0.2128 (0.2416)  loss_objectness: 0.0005 (0.0039)  loss_rpn_box_reg: 0.0021 (0.0028)  time: 0.5928  data: 0.0093  max mem: 6205
# Epoch: [0]  [ 70/159]  eta: 0:00:51  lr: 0.002250  loss: 0.4014 (0.6211)  loss_classifier: 0.1714 (0.3625)  loss_box_reg: 0.2214 (0.2522)  loss_objectness: 0.0001 (0.0035)  loss_rpn_box_reg: 0.0021 (0.0028)  time: 0.5735  data: 0.0101  max mem: 6205
# Epoch: [0]  [ 80/159]  eta: 0:00:45  lr: 0.002566  loss: 0.3911 (0.5982)  loss_classifier: 0.1714 (0.3411)  loss_box_reg: 0.2159 (0.2510)  loss_objectness: 0.0003 (0.0033)  loss_rpn_box_reg: 0.0022 (0.0028)  time: 0.5880  data: 0.0099  max mem: 6205
# Epoch: [0]  [ 90/159]  eta: 0:00:39  lr: 0.002882  loss: 0.3127 (0.5629)  loss_classifier: 0.1504 (0.3186)  loss_box_reg: 0.1667 (0.2385)  loss_objectness: 0.0010 (0.0031)  loss_rpn_box_reg: 0.0018 (0.0027)  time: 0.5756  data: 0.0106  max mem: 6205
# Epoch: [0]  [100/159]  eta: 0:00:34  lr: 0.003198  loss: 0.2805 (0.5409)  loss_classifier: 0.1344 (0.3055)  loss_box_reg: 0.1332 (0.2297)  loss_objectness: 0.0004 (0.0029)  loss_rpn_box_reg: 0.0024 (0.0027)  time: 0.6101  data: 0.0106  max mem: 6205
# Epoch: [0]  [110/159]  eta: 0:00:28  lr: 0.003514  loss: 0.2655 (0.5216)  loss_classifier: 0.1346 (0.2954)  loss_box_reg: 0.1149 (0.2209)  loss_objectness: 0.0001 (0.0026)  loss_rpn_box_reg: 0.0024 (0.0027)  time: 0.6440  data: 0.0111  max mem: 6205
# Epoch: [0]  [120/159]  eta: 0:00:22  lr: 0.003830  loss: 0.2282 (0.4976)  loss_classifier: 0.1346 (0.2830)  loss_box_reg: 0.0900 (0.2094)  loss_objectness: 0.0000 (0.0026)  loss_rpn_box_reg: 0.0020 (0.0026)  time: 0.6085  data: 0.0112  max mem: 6205
# Epoch: [0]  [130/159]  eta: 0:00:16  lr: 0.004146  loss: 0.2510 (0.4821)  loss_classifier: 0.1350 (0.2748)  loss_box_reg: 0.0949 (0.2021)  loss_objectness: 0.0001 (0.0025)  loss_rpn_box_reg: 0.0020 (0.0027)  time: 0.5696  data: 0.0121  max mem: 6205
# Epoch: [0]  [140/159]  eta: 0:00:11  lr: 0.004463  loss: 0.2337 (0.4673)  loss_classifier: 0.1350 (0.2679)  loss_box_reg: 0.0904 (0.1939)  loss_objectness: 0.0004 (0.0027)  loss_rpn_box_reg: 0.0029 (0.0026)  time: 0.5969  data: 0.0130  max mem: 6205
# Epoch: [0]  [150/159]  eta: 0:00:05  lr: 0.004779  loss: 0.2474 (0.4531)  loss_classifier: 0.1749 (0.2609)  loss_box_reg: 0.0867 (0.1869)  loss_objectness: 0.0004 (0.0026)  loss_rpn_box_reg: 0.0016 (0.0027)  time: 0.6098  data: 0.0101  max mem: 6205
# Epoch: [0]  [158/159]  eta: 0:00:00  lr: 0.005000  loss: 0.2337 (0.4409)  loss_classifier: 0.1553 (0.2551)  loss_box_reg: 0.0609 (0.1805)  loss_objectness: 0.0002 (0.0027)  loss_rpn_box_reg: 0.0017 (0.0026)  time: 0.5775  data: 0.0105  max mem: 6205
# Epoch: [0] Total time: 0:01:33 (0.5855 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:12  model_time: 0.1912 (0.1912)  evaluator_time: 0.0029 (0.0029)  time: 0.3020  data: 0.1060  max mem: 6205
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1090 (0.1141)  evaluator_time: 0.0016 (0.0019)  time: 0.1185  data: 0.0044  max mem: 6205
# Test: Total time: 0:00:05 (0.1259 s / it)
# Averaged stats: model_time: 0.1090 (0.1141)  evaluator_time: 0.0016 (0.0019)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [1]  [  0/159]  eta: 0:01:42  lr: 0.005000  loss: 0.3678 (0.3678)  loss_classifier: 0.2331 (0.2331)  loss_box_reg: 0.1324 (0.1324)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0021 (0.0021)  time: 0.6448  data: 0.1243  max mem: 6205
# Epoch: [1]  [ 10/159]  eta: 0:01:30  lr: 0.005000  loss: 0.3420 (0.2881)  loss_classifier: 0.2331 (0.1940)  loss_box_reg: 0.0913 (0.0909)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0021 (0.0027)  time: 0.6097  data: 0.0211  max mem: 6205
# Epoch: [1]  [ 20/159]  eta: 0:01:22  lr: 0.005000  loss: 0.1975 (0.2484)  loss_classifier: 0.1225 (0.1674)  loss_box_reg: 0.0665 (0.0764)  loss_objectness: 0.0005 (0.0019)  loss_rpn_box_reg: 0.0021 (0.0027)  time: 0.5876  data: 0.0093  max mem: 6205
# Epoch: [1]  [ 30/159]  eta: 0:01:14  lr: 0.005000  loss: 0.2152 (0.2549)  loss_classifier: 0.1493 (0.1713)  loss_box_reg: 0.0665 (0.0797)  loss_objectness: 0.0003 (0.0015)  loss_rpn_box_reg: 0.0019 (0.0025)  time: 0.5584  data: 0.0098  max mem: 6205
# Epoch: [1]  [ 40/159]  eta: 0:01:10  lr: 0.005000  loss: 0.2152 (0.2398)  loss_classifier: 0.1493 (0.1639)  loss_box_reg: 0.0610 (0.0724)  loss_objectness: 0.0001 (0.0013)  loss_rpn_box_reg: 0.0017 (0.0022)  time: 0.6017  data: 0.0100  max mem: 6205
# Epoch: [1]  [ 50/159]  eta: 0:01:03  lr: 0.005000  loss: 0.1697 (0.2291)  loss_classifier: 0.1068 (0.1560)  loss_box_reg: 0.0426 (0.0699)  loss_objectness: 0.0001 (0.0011)  loss_rpn_box_reg: 0.0010 (0.0020)  time: 0.6035  data: 0.0098  max mem: 6205
# Epoch: [1]  [ 60/159]  eta: 0:00:58  lr: 0.005000  loss: 0.1672 (0.2245)  loss_classifier: 0.1068 (0.1513)  loss_box_reg: 0.0547 (0.0701)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0015 (0.0021)  time: 0.5915  data: 0.0097  max mem: 6205
# Epoch: [1]  [ 70/159]  eta: 0:00:52  lr: 0.005000  loss: 0.1503 (0.2118)  loss_classifier: 0.0995 (0.1433)  loss_box_reg: 0.0493 (0.0656)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0013 (0.0019)  time: 0.6100  data: 0.0095  max mem: 6205
# Epoch: [1]  [ 80/159]  eta: 0:00:46  lr: 0.005000  loss: 0.1575 (0.2218)  loss_classifier: 0.1081 (0.1506)  loss_box_reg: 0.0493 (0.0682)  loss_objectness: 0.0001 (0.0010)  loss_rpn_box_reg: 0.0016 (0.0020)  time: 0.5890  data: 0.0103  max mem: 6205
# Epoch: [1]  [ 90/159]  eta: 0:00:40  lr: 0.005000  loss: 0.2251 (0.2249)  loss_classifier: 0.1651 (0.1526)  loss_box_reg: 0.0709 (0.0692)  loss_objectness: 0.0004 (0.0010)  loss_rpn_box_reg: 0.0020 (0.0021)  time: 0.5861  data: 0.0092  max mem: 6205
# Epoch: [1]  [100/159]  eta: 0:00:34  lr: 0.005000  loss: 0.1884 (0.2190)  loss_classifier: 0.1279 (0.1490)  loss_box_reg: 0.0597 (0.0670)  loss_objectness: 0.0001 (0.0009)  loss_rpn_box_reg: 0.0017 (0.0020)  time: 0.5744  data: 0.0103  max mem: 6205
# Epoch: [1]  [110/159]  eta: 0:00:29  lr: 0.005000  loss: 0.1602 (0.2182)  loss_classifier: 0.1111 (0.1486)  loss_box_reg: 0.0508 (0.0664)  loss_objectness: 0.0002 (0.0011)  loss_rpn_box_reg: 0.0012 (0.0020)  time: 0.5919  data: 0.0100  max mem: 6205
# Epoch: [1]  [120/159]  eta: 0:00:23  lr: 0.005000  loss: 0.1430 (0.2157)  loss_classifier: 0.0897 (0.1468)  loss_box_reg: 0.0419 (0.0658)  loss_objectness: 0.0003 (0.0010)  loss_rpn_box_reg: 0.0012 (0.0020)  time: 0.6074  data: 0.0098  max mem: 6205
# Epoch: [1]  [130/159]  eta: 0:00:17  lr: 0.005000  loss: 0.1430 (0.2143)  loss_classifier: 0.0896 (0.1461)  loss_box_reg: 0.0396 (0.0650)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0016 (0.0020)  time: 0.5904  data: 0.0098  max mem: 6205
# Epoch: [1]  [140/159]  eta: 0:00:11  lr: 0.005000  loss: 0.1726 (0.2149)  loss_classifier: 0.1239 (0.1468)  loss_box_reg: 0.0456 (0.0650)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0019 (0.0020)  time: 0.5612  data: 0.0093  max mem: 6205
# Epoch: [1]  [150/159]  eta: 0:00:05  lr: 0.005000  loss: 0.1365 (0.2106)  loss_classifier: 0.0988 (0.1439)  loss_box_reg: 0.0398 (0.0637)  loss_objectness: 0.0001 (0.0010)  loss_rpn_box_reg: 0.0018 (0.0020)  time: 0.5628  data: 0.0094  max mem: 6205
# Epoch: [1]  [158/159]  eta: 0:00:00  lr: 0.005000  loss: 0.1667 (0.2097)  loss_classifier: 0.1026 (0.1433)  loss_box_reg: 0.0575 (0.0634)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0017 (0.0020)  time: 0.6024  data: 0.0086  max mem: 6205
# Epoch: [1] Total time: 0:01:33 (0.5911 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:10  model_time: 0.1543 (0.1543)  evaluator_time: 0.0037 (0.0037)  time: 0.2661  data: 0.1063  max mem: 6205
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1114 (0.1144)  evaluator_time: 0.0015 (0.0020)  time: 0.1205  data: 0.0046  max mem: 6205
# Test: Total time: 0:00:05 (0.1259 s / it)
# Averaged stats: model_time: 0.1114 (0.1144)  evaluator_time: 0.0015 (0.0020)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [2]  [  0/159]  eta: 0:01:44  lr: 0.005000  loss: 0.0750 (0.0750)  loss_classifier: 0.0649 (0.0649)  loss_box_reg: 0.0100 (0.0100)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0001 (0.0001)  time: 0.6603  data: 0.1457  max mem: 6205
# Epoch: [2]  [ 10/159]  eta: 0:01:28  lr: 0.005000  loss: 0.1825 (0.1895)  loss_classifier: 0.1334 (0.1372)  loss_box_reg: 0.0580 (0.0510)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0012 (0.0010)  time: 0.5955  data: 0.0219  max mem: 6205
# Epoch: [2]  [ 20/159]  eta: 0:01:23  lr: 0.005000  loss: 0.1534 (0.1631)  loss_classifier: 0.1002 (0.1167)  loss_box_reg: 0.0396 (0.0451)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6015  data: 0.0088  max mem: 6205
# Epoch: [2]  [ 30/159]  eta: 0:01:18  lr: 0.005000  loss: 0.1312 (0.1813)  loss_classifier: 0.0746 (0.1269)  loss_box_reg: 0.0362 (0.0530)  loss_objectness: 0.0000 (0.0003)  loss_rpn_box_reg: 0.0008 (0.0011)  time: 0.6173  data: 0.0091  max mem: 6205
# Epoch: [2]  [ 40/159]  eta: 0:01:11  lr: 0.005000  loss: 0.1323 (0.1736)  loss_classifier: 0.0912 (0.1194)  loss_box_reg: 0.0350 (0.0524)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0012 (0.0013)  time: 0.6045  data: 0.0099  max mem: 6205
# Epoch: [2]  [ 50/159]  eta: 0:01:04  lr: 0.005000  loss: 0.1270 (0.1716)  loss_classifier: 0.0821 (0.1194)  loss_box_reg: 0.0360 (0.0504)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0014 (0.0013)  time: 0.5721  data: 0.0088  max mem: 6205
# Epoch: [2]  [ 60/159]  eta: 0:00:59  lr: 0.005000  loss: 0.1468 (0.1802)  loss_classifier: 0.1051 (0.1259)  loss_box_reg: 0.0435 (0.0523)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0014 (0.0013)  time: 0.6023  data: 0.0094  max mem: 6205
# Epoch: [2]  [ 70/159]  eta: 0:00:53  lr: 0.005000  loss: 0.1575 (0.1795)  loss_classifier: 0.1030 (0.1239)  loss_box_reg: 0.0575 (0.0536)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0015 (0.0014)  time: 0.6021  data: 0.0093  max mem: 6205
# Epoch: [2]  [ 80/159]  eta: 0:00:46  lr: 0.005000  loss: 0.1575 (0.1797)  loss_classifier: 0.0978 (0.1253)  loss_box_reg: 0.0415 (0.0525)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0011 (0.0013)  time: 0.5491  data: 0.0104  max mem: 6205
# Epoch: [2]  [ 90/159]  eta: 0:00:40  lr: 0.005000  loss: 0.1541 (0.1752)  loss_classifier: 0.1095 (0.1224)  loss_box_reg: 0.0326 (0.0510)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0009 (0.0013)  time: 0.5678  data: 0.0107  max mem: 6205
# Epoch: [2]  [100/159]  eta: 0:00:35  lr: 0.005000  loss: 0.1135 (0.1723)  loss_classifier: 0.0801 (0.1214)  loss_box_reg: 0.0303 (0.0491)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0007 (0.0012)  time: 0.6214  data: 0.0105  max mem: 6205
# Epoch: [2]  [110/159]  eta: 0:00:29  lr: 0.005000  loss: 0.1002 (0.1742)  loss_classifier: 0.0769 (0.1236)  loss_box_reg: 0.0303 (0.0488)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0008 (0.0012)  time: 0.6328  data: 0.0104  max mem: 6205
# Epoch: [2]  [120/159]  eta: 0:00:23  lr: 0.005000  loss: 0.1405 (0.1729)  loss_classifier: 0.0844 (0.1229)  loss_box_reg: 0.0396 (0.0482)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0011 (0.0012)  time: 0.6335  data: 0.0102  max mem: 6205
# Epoch: [2]  [130/159]  eta: 0:00:17  lr: 0.005000  loss: 0.1347 (0.1725)  loss_classifier: 0.0985 (0.1233)  loss_box_reg: 0.0383 (0.0473)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0010 (0.0013)  time: 0.6081  data: 0.0101  max mem: 6205
# Epoch: [2]  [140/159]  eta: 0:00:11  lr: 0.005000  loss: 0.1347 (0.1721)  loss_classifier: 0.0985 (0.1234)  loss_box_reg: 0.0353 (0.0468)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0008 (0.0012)  time: 0.5787  data: 0.0083  max mem: 6205
# Epoch: [2]  [150/159]  eta: 0:00:05  lr: 0.005000  loss: 0.1472 (0.1731)  loss_classifier: 0.1060 (0.1249)  loss_box_reg: 0.0353 (0.0464)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0007 (0.0012)  time: 0.5940  data: 0.0089  max mem: 6205
# Epoch: [2]  [158/159]  eta: 0:00:00  lr: 0.005000  loss: 0.1587 (0.1719)  loss_classifier: 0.1286 (0.1244)  loss_box_reg: 0.0344 (0.0457)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0007 (0.0012)  time: 0.6078  data: 0.0087  max mem: 6205
# Epoch: [2] Total time: 0:01:35 (0.6011 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:10  model_time: 0.1611 (0.1611)  evaluator_time: 0.0027 (0.0027)  time: 0.2744  data: 0.1065  max mem: 6205
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1118 (0.1151)  evaluator_time: 0.0015 (0.0019)  time: 0.1205  data: 0.0044  max mem: 6205
# Test: Total time: 0:00:05 (0.1266 s / it)
# Averaged stats: model_time: 0.1118 (0.1151)  evaluator_time: 0.0015 (0.0019)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [3]  [  0/159]  eta: 0:01:47  lr: 0.000500  loss: 0.1066 (0.1066)  loss_classifier: 0.0781 (0.0781)  loss_box_reg: 0.0282 (0.0282)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0004 (0.0004)  time: 0.6784  data: 0.1390  max mem: 6205
# Epoch: [3]  [ 10/159]  eta: 0:01:36  lr: 0.000500  loss: 0.1665 (0.1666)  loss_classifier: 0.1083 (0.1216)  loss_box_reg: 0.0384 (0.0440)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.6465  data: 0.0206  max mem: 6205
# Epoch: [3]  [ 20/159]  eta: 0:01:24  lr: 0.000500  loss: 0.1665 (0.1651)  loss_classifier: 0.1103 (0.1219)  loss_box_reg: 0.0425 (0.0421)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 0.6009  data: 0.0089  max mem: 6205
# Epoch: [3]  [ 30/159]  eta: 0:01:19  lr: 0.000500  loss: 0.1652 (0.1719)  loss_classifier: 0.1202 (0.1281)  loss_box_reg: 0.0353 (0.0423)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0007 (0.0011)  time: 0.6022  data: 0.0086  max mem: 6205
# Epoch: [3]  [ 40/159]  eta: 0:01:14  lr: 0.000500  loss: 0.1415 (0.1564)  loss_classifier: 0.1014 (0.1183)  loss_box_reg: 0.0296 (0.0368)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 0.6470  data: 0.0089  max mem: 6205
# Epoch: [3]  [ 50/159]  eta: 0:01:07  lr: 0.000500  loss: 0.0884 (0.1534)  loss_classifier: 0.0618 (0.1177)  loss_box_reg: 0.0159 (0.0345)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 0.6169  data: 0.0088  max mem: 6205
# Epoch: [3]  [ 60/159]  eta: 0:01:00  lr: 0.000500  loss: 0.1000 (0.1536)  loss_classifier: 0.0851 (0.1190)  loss_box_reg: 0.0207 (0.0334)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.5918  data: 0.0093  max mem: 6205
# Epoch: [3]  [ 70/159]  eta: 0:00:54  lr: 0.000500  loss: 0.1217 (0.1572)  loss_classifier: 0.0867 (0.1214)  loss_box_reg: 0.0286 (0.0345)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 0.5913  data: 0.0094  max mem: 6205
# Epoch: [3]  [ 80/159]  eta: 0:00:48  lr: 0.000500  loss: 0.1432 (0.1608)  loss_classifier: 0.0979 (0.1245)  loss_box_reg: 0.0283 (0.0350)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.6349  data: 0.0104  max mem: 6205
# Epoch: [3]  [ 90/159]  eta: 0:00:42  lr: 0.000500  loss: 0.1569 (0.1610)  loss_classifier: 0.1293 (0.1249)  loss_box_reg: 0.0245 (0.0349)  loss_objectness: 0.0000 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.6489  data: 0.0103  max mem: 6205
# Epoch: [3]  [100/159]  eta: 0:00:36  lr: 0.000500  loss: 0.1134 (0.1548)  loss_classifier: 0.0859 (0.1202)  loss_box_reg: 0.0183 (0.0334)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.6017  data: 0.0101  max mem: 6205
# Epoch: [3]  [110/159]  eta: 0:00:30  lr: 0.000500  loss: 0.0857 (0.1539)  loss_classifier: 0.0709 (0.1198)  loss_box_reg: 0.0170 (0.0328)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.6162  data: 0.0102  max mem: 6205
# Epoch: [3]  [120/159]  eta: 0:00:24  lr: 0.000500  loss: 0.0976 (0.1512)  loss_classifier: 0.0748 (0.1181)  loss_box_reg: 0.0152 (0.0318)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.6172  data: 0.0098  max mem: 6205
# Epoch: [3]  [130/159]  eta: 0:00:17  lr: 0.000500  loss: 0.1078 (0.1508)  loss_classifier: 0.0846 (0.1183)  loss_box_reg: 0.0218 (0.0312)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.6203  data: 0.0112  max mem: 6205
# Epoch: [3]  [140/159]  eta: 0:00:11  lr: 0.000500  loss: 0.1054 (0.1477)  loss_classifier: 0.0811 (0.1159)  loss_box_reg: 0.0218 (0.0306)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.5899  data: 0.0112  max mem: 6205
# Epoch: [3]  [150/159]  eta: 0:00:05  lr: 0.000500  loss: 0.0955 (0.1471)  loss_classifier: 0.0739 (0.1155)  loss_box_reg: 0.0213 (0.0304)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.5721  data: 0.0099  max mem: 6205
# Epoch: [3]  [158/159]  eta: 0:00:00  lr: 0.000500  loss: 0.1030 (0.1465)  loss_classifier: 0.0840 (0.1150)  loss_box_reg: 0.0187 (0.0301)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.5857  data: 0.0088  max mem: 6205
# Epoch: [3] Total time: 0:01:37 (0.6106 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:10  model_time: 0.1594 (0.1594)  evaluator_time: 0.0029 (0.0029)  time: 0.2660  data: 0.1019  max mem: 6205
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1118 (0.1146)  evaluator_time: 0.0016 (0.0018)  time: 0.1203  data: 0.0044  max mem: 6205
# Test: Total time: 0:00:05 (0.1258 s / it)
# Averaged stats: model_time: 0.1118 (0.1146)  evaluator_time: 0.0016 (0.0018)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [4]  [  0/159]  eta: 0:01:43  lr: 0.000500  loss: 0.2493 (0.2493)  loss_classifier: 0.2077 (0.2077)  loss_box_reg: 0.0410 (0.0410)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0006 (0.0006)  time: 0.6516  data: 0.1334  max mem: 6205
# Epoch: [4]  [ 10/159]  eta: 0:01:24  lr: 0.000500  loss: 0.2066 (0.1971)  loss_classifier: 0.1684 (0.1605)  loss_box_reg: 0.0354 (0.0350)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0008 (0.0012)  time: 0.5658  data: 0.0216  max mem: 6206
# Epoch: [4]  [ 20/159]  eta: 0:01:21  lr: 0.000500  loss: 0.1644 (0.1822)  loss_classifier: 0.1390 (0.1492)  loss_box_reg: 0.0280 (0.0317)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.5861  data: 0.0093  max mem: 6206
# Epoch: [4]  [ 30/159]  eta: 0:01:22  lr: 0.000500  loss: 0.1263 (0.1719)  loss_classifier: 0.0982 (0.1429)  loss_box_reg: 0.0256 (0.0279)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.6760  data: 0.0105  max mem: 6206
# Epoch: [4]  [ 40/159]  eta: 0:01:13  lr: 0.000500  loss: 0.1121 (0.1720)  loss_classifier: 0.0908 (0.1428)  loss_box_reg: 0.0141 (0.0278)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.6483  data: 0.0108  max mem: 6206
# Epoch: [4]  [ 50/159]  eta: 0:01:08  lr: 0.000500  loss: 0.1368 (0.1695)  loss_classifier: 0.1131 (0.1396)  loss_box_reg: 0.0233 (0.0284)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.6220  data: 0.0092  max mem: 6206
# Epoch: [4]  [ 60/159]  eta: 0:01:02  lr: 0.000500  loss: 0.1172 (0.1640)  loss_classifier: 0.0979 (0.1356)  loss_box_reg: 0.0210 (0.0270)  loss_objectness: 0.0000 (0.0005)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.6662  data: 0.0097  max mem: 6206
# Epoch: [4]  [ 70/159]  eta: 0:00:56  lr: 0.000500  loss: 0.0786 (0.1574)  loss_classifier: 0.0629 (0.1298)  loss_box_reg: 0.0184 (0.0263)  loss_objectness: 0.0000 (0.0005)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.6336  data: 0.0101  max mem: 6206
# Epoch: [4]  [ 80/159]  eta: 0:00:49  lr: 0.000500  loss: 0.0984 (0.1520)  loss_classifier: 0.0697 (0.1245)  loss_box_reg: 0.0267 (0.0263)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.6036  data: 0.0106  max mem: 6206
# Epoch: [4]  [ 90/159]  eta: 0:00:43  lr: 0.000500  loss: 0.0985 (0.1476)  loss_classifier: 0.0701 (0.1210)  loss_box_reg: 0.0173 (0.0253)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.5999  data: 0.0096  max mem: 6206
# Epoch: [4]  [100/159]  eta: 0:00:36  lr: 0.000500  loss: 0.0862 (0.1435)  loss_classifier: 0.0672 (0.1170)  loss_box_reg: 0.0113 (0.0252)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0008)  time: 0.5870  data: 0.0098  max mem: 6206
# Epoch: [4]  [110/159]  eta: 0:00:30  lr: 0.000500  loss: 0.0984 (0.1424)  loss_classifier: 0.0698 (0.1163)  loss_box_reg: 0.0189 (0.0249)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0008)  time: 0.5868  data: 0.0098  max mem: 6206
# Epoch: [4]  [120/159]  eta: 0:00:24  lr: 0.000500  loss: 0.0987 (0.1389)  loss_classifier: 0.0698 (0.1133)  loss_box_reg: 0.0192 (0.0245)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0008)  time: 0.5997  data: 0.0095  max mem: 6206
# Epoch: [4]  [130/159]  eta: 0:00:17  lr: 0.000500  loss: 0.0987 (0.1392)  loss_classifier: 0.0738 (0.1133)  loss_box_reg: 0.0230 (0.0248)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0003 (0.0008)  time: 0.5709  data: 0.0097  max mem: 6206
# Epoch: [4]  [140/159]  eta: 0:00:11  lr: 0.000500  loss: 0.0787 (0.1352)  loss_classifier: 0.0649 (0.1100)  loss_box_reg: 0.0169 (0.0241)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.5848  data: 0.0090  max mem: 6206
# Epoch: [4]  [150/159]  eta: 0:00:05  lr: 0.000500  loss: 0.0710 (0.1337)  loss_classifier: 0.0559 (0.1088)  loss_box_reg: 0.0134 (0.0239)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.6283  data: 0.0090  max mem: 6206
# Epoch: [4]  [158/159]  eta: 0:00:00  lr: 0.000500  loss: 0.1001 (0.1381)  loss_classifier: 0.0812 (0.1114)  loss_box_reg: 0.0215 (0.0256)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.6424  data: 0.0087  max mem: 6206
# Epoch: [4] Total time: 0:01:37 (0.6129 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:10  model_time: 0.1592 (0.1592)  evaluator_time: 0.0028 (0.0028)  time: 0.2719  data: 0.1081  max mem: 6206
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1130 (0.1208)  evaluator_time: 0.0016 (0.0020)  time: 0.1329  data: 0.0048  max mem: 6206
# Test: Total time: 0:00:05 (0.1330 s / it)
# Averaged stats: model_time: 0.1130 (0.1208)  evaluator_time: 0.0016 (0.0020)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [5]  [  0/159]  eta: 0:01:45  lr: 0.000500  loss: 0.1283 (0.1283)  loss_classifier: 0.0935 (0.0935)  loss_box_reg: 0.0336 (0.0336)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0011 (0.0011)  time: 0.6661  data: 0.1529  max mem: 6206
# Epoch: [5]  [ 10/159]  eta: 0:01:20  lr: 0.000500  loss: 0.1238 (0.1336)  loss_classifier: 0.0935 (0.1058)  loss_box_reg: 0.0178 (0.0265)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.5433  data: 0.0236  max mem: 6206
# Epoch: [5]  [ 20/159]  eta: 0:01:18  lr: 0.000500  loss: 0.0925 (0.1433)  loss_classifier: 0.0726 (0.1159)  loss_box_reg: 0.0213 (0.0261)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.5582  data: 0.0094  max mem: 6206
# Epoch: [5]  [ 30/159]  eta: 0:01:13  lr: 0.000500  loss: 0.1460 (0.1500)  loss_classifier: 0.1247 (0.1197)  loss_box_reg: 0.0219 (0.0289)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.5880  data: 0.0096  max mem: 6206
# Epoch: [5]  [ 40/159]  eta: 0:01:08  lr: 0.000500  loss: 0.1216 (0.1436)  loss_classifier: 0.0845 (0.1152)  loss_box_reg: 0.0195 (0.0271)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.5902  data: 0.0100  max mem: 6206
# Epoch: [5]  [ 50/159]  eta: 0:01:03  lr: 0.000500  loss: 0.1157 (0.1403)  loss_classifier: 0.0779 (0.1130)  loss_box_reg: 0.0216 (0.0261)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.5891  data: 0.0087  max mem: 6206
# Epoch: [5]  [ 60/159]  eta: 0:00:58  lr: 0.000500  loss: 0.1077 (0.1440)  loss_classifier: 0.0956 (0.1172)  loss_box_reg: 0.0223 (0.0256)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0008)  time: 0.6196  data: 0.0092  max mem: 6206
# Epoch: [5]  [ 70/159]  eta: 0:00:52  lr: 0.000500  loss: 0.1077 (0.1449)  loss_classifier: 0.0924 (0.1171)  loss_box_reg: 0.0236 (0.0265)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0008)  time: 0.6043  data: 0.0093  max mem: 6206
# Epoch: [5]  [ 80/159]  eta: 0:00:46  lr: 0.000500  loss: 0.1332 (0.1445)  loss_classifier: 0.0922 (0.1170)  loss_box_reg: 0.0254 (0.0263)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.5901  data: 0.0105  max mem: 6206
# Epoch: [5]  [ 90/159]  eta: 0:00:41  lr: 0.000500  loss: 0.0954 (0.1402)  loss_classifier: 0.0737 (0.1134)  loss_box_reg: 0.0202 (0.0256)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.6328  data: 0.0106  max mem: 6206
# Epoch: [5]  [100/159]  eta: 0:00:34  lr: 0.000500  loss: 0.1254 (0.1428)  loss_classifier: 0.0958 (0.1150)  loss_box_reg: 0.0208 (0.0264)  loss_objectness: 0.0000 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.6040  data: 0.0093  max mem: 6206
# Epoch: [5]  [110/159]  eta: 0:00:29  lr: 0.000500  loss: 0.1435 (0.1402)  loss_classifier: 0.1019 (0.1131)  loss_box_reg: 0.0238 (0.0258)  loss_objectness: 0.0000 (0.0005)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.6182  data: 0.0092  max mem: 6206
# Epoch: [5]  [120/159]  eta: 0:00:23  lr: 0.000500  loss: 0.0969 (0.1405)  loss_classifier: 0.0734 (0.1132)  loss_box_reg: 0.0238 (0.0260)  loss_objectness: 0.0000 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.6170  data: 0.0107  max mem: 6206
# Epoch: [5]  [130/159]  eta: 0:00:17  lr: 0.000500  loss: 0.0713 (0.1361)  loss_classifier: 0.0589 (0.1097)  loss_box_reg: 0.0126 (0.0252)  loss_objectness: 0.0000 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.5759  data: 0.0105  max mem: 6206
# Epoch: [5]  [140/159]  eta: 0:00:11  lr: 0.000500  loss: 0.0713 (0.1359)  loss_classifier: 0.0589 (0.1100)  loss_box_reg: 0.0119 (0.0248)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.6089  data: 0.0099  max mem: 6206
# Epoch: [5]  [150/159]  eta: 0:00:05  lr: 0.000500  loss: 0.0945 (0.1345)  loss_classifier: 0.0729 (0.1090)  loss_box_reg: 0.0158 (0.0244)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.6528  data: 0.0105  max mem: 6206
# Epoch: [5]  [158/159]  eta: 0:00:00  lr: 0.000500  loss: 0.0945 (0.1368)  loss_classifier: 0.0729 (0.1107)  loss_box_reg: 0.0167 (0.0249)  loss_objectness: 0.0000 (0.0005)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.6320  data: 0.0095  max mem: 6206
# Epoch: [5] Total time: 0:01:36 (0.6045 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:10  model_time: 0.1554 (0.1554)  evaluator_time: 0.0031 (0.0031)  time: 0.2694  data: 0.1091  max mem: 6206
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1119 (0.1146)  evaluator_time: 0.0016 (0.0020)  time: 0.1211  data: 0.0047  max mem: 6206
# Test: Total time: 0:00:05 (0.1266 s / it)
# Averaged stats: model_time: 0.1119 (0.1146)  evaluator_time: 0.0016 (0.0020)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [6]  [  0/159]  eta: 0:01:43  lr: 0.000050  loss: 0.1833 (0.1833)  loss_classifier: 0.1574 (0.1574)  loss_box_reg: 0.0256 (0.0256)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6530  data: 0.1308  max mem: 6206
# Epoch: [6]  [ 10/159]  eta: 0:01:24  lr: 0.000050  loss: 0.1022 (0.1519)  loss_classifier: 0.0713 (0.1266)  loss_box_reg: 0.0238 (0.0242)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.5682  data: 0.0228  max mem: 6206
# Epoch: [6]  [ 20/159]  eta: 0:01:24  lr: 0.000050  loss: 0.0881 (0.1285)  loss_classifier: 0.0701 (0.1056)  loss_box_reg: 0.0172 (0.0218)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.6019  data: 0.0102  max mem: 6206
# Epoch: [6]  [ 30/159]  eta: 0:01:16  lr: 0.000050  loss: 0.1139 (0.1380)  loss_classifier: 0.0964 (0.1143)  loss_box_reg: 0.0199 (0.0227)  loss_objectness: 0.0000 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.6023  data: 0.0090  max mem: 6206
# Epoch: [6]  [ 40/159]  eta: 0:01:08  lr: 0.000050  loss: 0.1779 (0.1439)  loss_classifier: 0.1440 (0.1188)  loss_box_reg: 0.0253 (0.0241)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 0.5478  data: 0.0102  max mem: 6206
# Epoch: [6]  [ 50/159]  eta: 0:01:03  lr: 0.000050  loss: 0.1536 (0.1444)  loss_classifier: 0.1084 (0.1196)  loss_box_reg: 0.0204 (0.0238)  loss_objectness: 0.0000 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.5762  data: 0.0095  max mem: 6206
# Epoch: [6]  [ 60/159]  eta: 0:00:57  lr: 0.000050  loss: 0.1157 (0.1385)  loss_classifier: 0.1026 (0.1153)  loss_box_reg: 0.0139 (0.0223)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 0.5850  data: 0.0110  max mem: 6206
# Epoch: [6]  [ 70/159]  eta: 0:00:52  lr: 0.000050  loss: 0.1047 (0.1331)  loss_classifier: 0.0893 (0.1103)  loss_box_reg: 0.0124 (0.0218)  loss_objectness: 0.0000 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 0.5998  data: 0.0118  max mem: 6206
# Epoch: [6]  [ 80/159]  eta: 0:00:47  lr: 0.000050  loss: 0.0888 (0.1326)  loss_classifier: 0.0667 (0.1090)  loss_box_reg: 0.0198 (0.0227)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.6492  data: 0.0108  max mem: 6206
# Epoch: [6]  [ 90/159]  eta: 0:00:41  lr: 0.000050  loss: 0.0851 (0.1289)  loss_classifier: 0.0638 (0.1055)  loss_box_reg: 0.0176 (0.0224)  loss_objectness: 0.0000 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.6179  data: 0.0098  max mem: 6206
# Epoch: [6]  [100/159]  eta: 0:00:35  lr: 0.000050  loss: 0.0796 (0.1280)  loss_classifier: 0.0627 (0.1046)  loss_box_reg: 0.0172 (0.0224)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.5907  data: 0.0096  max mem: 6206
# Epoch: [6]  [110/159]  eta: 0:00:29  lr: 0.000050  loss: 0.0922 (0.1285)  loss_classifier: 0.0723 (0.1045)  loss_box_reg: 0.0188 (0.0229)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.6052  data: 0.0101  max mem: 6206
# Epoch: [6]  [120/159]  eta: 0:00:23  lr: 0.000050  loss: 0.0805 (0.1275)  loss_classifier: 0.0707 (0.1038)  loss_box_reg: 0.0185 (0.0226)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.6023  data: 0.0109  max mem: 6206
# Epoch: [6]  [130/159]  eta: 0:00:17  lr: 0.000050  loss: 0.1166 (0.1303)  loss_classifier: 0.0780 (0.1064)  loss_box_reg: 0.0205 (0.0229)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.5964  data: 0.0131  max mem: 6206
# Epoch: [6]  [140/159]  eta: 0:00:11  lr: 0.000050  loss: 0.1214 (0.1310)  loss_classifier: 0.0780 (0.1073)  loss_box_reg: 0.0169 (0.0226)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.6353  data: 0.0108  max mem: 6206
# Epoch: [6]  [150/159]  eta: 0:00:05  lr: 0.000050  loss: 0.1406 (0.1330)  loss_classifier: 0.0919 (0.1089)  loss_box_reg: 0.0198 (0.0230)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.6299  data: 0.0103  max mem: 6206
# Epoch: [6]  [158/159]  eta: 0:00:00  lr: 0.000050  loss: 0.1122 (0.1331)  loss_classifier: 0.0886 (0.1089)  loss_box_reg: 0.0211 (0.0231)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.6452  data: 0.0103  max mem: 6206
# Epoch: [6] Total time: 0:01:36 (0.6053 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:13  model_time: 0.1632 (0.1632)  evaluator_time: 0.0043 (0.0043)  time: 0.3360  data: 0.1658  max mem: 6206
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1110 (0.1146)  evaluator_time: 0.0016 (0.0025)  time: 0.1205  data: 0.0048  max mem: 6206
# Test: Total time: 0:00:05 (0.1312 s / it)
# Averaged stats: model_time: 0.1110 (0.1146)  evaluator_time: 0.0016 (0.0025)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [7]  [  0/159]  eta: 0:02:36  lr: 0.000050  loss: 0.3542 (0.3542)  loss_classifier: 0.3088 (0.3088)  loss_box_reg: 0.0437 (0.0437)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0015 (0.0015)  time: 0.9836  data: 0.1704  max mem: 6206
# Epoch: [7]  [ 10/159]  eta: 0:01:32  lr: 0.000050  loss: 0.1395 (0.1623)  loss_classifier: 0.0895 (0.1313)  loss_box_reg: 0.0237 (0.0293)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0010 (0.0011)  time: 0.6194  data: 0.0222  max mem: 6206
# Epoch: [7]  [ 20/159]  eta: 0:01:26  lr: 0.000050  loss: 0.0991 (0.1448)  loss_classifier: 0.0764 (0.1189)  loss_box_reg: 0.0219 (0.0247)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.6066  data: 0.0100  max mem: 6206
# Epoch: [7]  [ 30/159]  eta: 0:01:18  lr: 0.000050  loss: 0.0853 (0.1347)  loss_classifier: 0.0571 (0.1113)  loss_box_reg: 0.0185 (0.0224)  loss_objectness: 0.0000 (0.0002)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.6086  data: 0.0104  max mem: 6206
# Epoch: [7]  [ 40/159]  eta: 0:01:12  lr: 0.000050  loss: 0.0658 (0.1212)  loss_classifier: 0.0526 (0.1005)  loss_box_reg: 0.0115 (0.0198)  loss_objectness: 0.0000 (0.0002)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.5901  data: 0.0097  max mem: 6206
# Epoch: [7]  [ 50/159]  eta: 0:01:05  lr: 0.000050  loss: 0.0663 (0.1170)  loss_classifier: 0.0592 (0.0968)  loss_box_reg: 0.0095 (0.0194)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0003 (0.0006)  time: 0.5905  data: 0.0098  max mem: 6206
# Epoch: [7]  [ 60/159]  eta: 0:00:59  lr: 0.000050  loss: 0.1041 (0.1212)  loss_classifier: 0.0820 (0.0998)  loss_box_reg: 0.0201 (0.0206)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.5900  data: 0.0104  max mem: 6206
# Epoch: [7]  [ 70/159]  eta: 0:00:53  lr: 0.000050  loss: 0.1308 (0.1209)  loss_classifier: 0.1141 (0.0996)  loss_box_reg: 0.0186 (0.0203)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.5900  data: 0.0112  max mem: 6206
# Epoch: [7]  [ 80/159]  eta: 0:00:47  lr: 0.000050  loss: 0.1308 (0.1242)  loss_classifier: 0.1058 (0.1025)  loss_box_reg: 0.0182 (0.0208)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 0.6179  data: 0.0104  max mem: 6206
# Epoch: [7]  [ 90/159]  eta: 0:00:42  lr: 0.000050  loss: 0.1061 (0.1233)  loss_classifier: 0.0843 (0.1015)  loss_box_reg: 0.0188 (0.0209)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 0.6512  data: 0.0108  max mem: 6206
# Epoch: [7]  [100/159]  eta: 0:00:36  lr: 0.000050  loss: 0.1200 (0.1255)  loss_classifier: 0.0962 (0.1038)  loss_box_reg: 0.0191 (0.0209)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 0.6553  data: 0.0108  max mem: 6206
# Epoch: [7]  [110/159]  eta: 0:00:29  lr: 0.000050  loss: 0.1227 (0.1267)  loss_classifier: 0.1073 (0.1046)  loss_box_reg: 0.0191 (0.0212)  loss_objectness: 0.0000 (0.0002)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 0.5935  data: 0.0106  max mem: 6206
# Epoch: [7]  [120/159]  eta: 0:00:23  lr: 0.000050  loss: 0.1164 (0.1284)  loss_classifier: 0.0868 (0.1059)  loss_box_reg: 0.0190 (0.0217)  loss_objectness: 0.0000 (0.0002)  loss_rpn_box_reg: 0.0003 (0.0006)  time: 0.5432  data: 0.0094  max mem: 6206
# Epoch: [7]  [130/159]  eta: 0:00:17  lr: 0.000050  loss: 0.1420 (0.1292)  loss_classifier: 0.0992 (0.1061)  loss_box_reg: 0.0204 (0.0223)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.5738  data: 0.0105  max mem: 6206
# Epoch: [7]  [140/159]  eta: 0:00:11  lr: 0.000050  loss: 0.1134 (0.1295)  loss_classifier: 0.0898 (0.1062)  loss_box_reg: 0.0206 (0.0224)  loss_objectness: 0.0000 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.5879  data: 0.0105  max mem: 6206
# Epoch: [7]  [150/159]  eta: 0:00:05  lr: 0.000050  loss: 0.1068 (0.1302)  loss_classifier: 0.0797 (0.1068)  loss_box_reg: 0.0197 (0.0226)  loss_objectness: 0.0000 (0.0002)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.6304  data: 0.0094  max mem: 6206
# Epoch: [7]  [158/159]  eta: 0:00:00  lr: 0.000050  loss: 0.1129 (0.1316)  loss_classifier: 0.0943 (0.1082)  loss_box_reg: 0.0193 (0.0225)  loss_objectness: 0.0000 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.6462  data: 0.0092  max mem: 6206
# Epoch: [7] Total time: 0:01:36 (0.6085 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:11  model_time: 0.1597 (0.1597)  evaluator_time: 0.0040 (0.0040)  time: 0.2784  data: 0.1127  max mem: 6206
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1133 (0.1163)  evaluator_time: 0.0023 (0.0028)  time: 0.1257  data: 0.0075  max mem: 6206
# Test: Total time: 0:00:05 (0.1328 s / it)
# Averaged stats: model_time: 0.1133 (0.1163)  evaluator_time: 0.0023 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [8]  [  0/159]  eta: 0:01:46  lr: 0.000050  loss: 0.0932 (0.0932)  loss_classifier: 0.0814 (0.0814)  loss_box_reg: 0.0107 (0.0107)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 0.6679  data: 0.1348  max mem: 6206
# Epoch: [8]  [ 10/159]  eta: 0:01:35  lr: 0.000050  loss: 0.1398 (0.1609)  loss_classifier: 0.1206 (0.1282)  loss_box_reg: 0.0194 (0.0314)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 0.6441  data: 0.0200  max mem: 6206
# Epoch: [8]  [ 20/159]  eta: 0:01:26  lr: 0.000050  loss: 0.1070 (0.1377)  loss_classifier: 0.0874 (0.1075)  loss_box_reg: 0.0194 (0.0291)  loss_objectness: 0.0000 (0.0002)  loss_rpn_box_reg: 0.0004 (0.0009)  time: 0.6168  data: 0.0104  max mem: 6206
# Epoch: [8]  [ 30/159]  eta: 0:01:21  lr: 0.000050  loss: 0.0789 (0.1331)  loss_classifier: 0.0629 (0.1069)  loss_box_reg: 0.0150 (0.0252)  loss_objectness: 0.0000 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0008)  time: 0.6191  data: 0.0103  max mem: 6206
# Epoch: [8]  [ 40/159]  eta: 0:01:16  lr: 0.000050  loss: 0.0913 (0.1323)  loss_classifier: 0.0761 (0.1075)  loss_box_reg: 0.0166 (0.0238)  loss_objectness: 0.0000 (0.0002)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.6641  data: 0.0106  max mem: 6206
# Epoch: [8]  [ 50/159]  eta: 0:01:10  lr: 0.000050  loss: 0.1300 (0.1379)  loss_classifier: 0.1212 (0.1134)  loss_box_reg: 0.0204 (0.0236)  loss_objectness: 0.0000 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.6644  data: 0.0106  max mem: 6206
# Epoch: [8]  [ 60/159]  eta: 0:01:02  lr: 0.000050  loss: 0.1028 (0.1347)  loss_classifier: 0.0794 (0.1107)  loss_box_reg: 0.0147 (0.0230)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.6200  data: 0.0106  max mem: 6206
# Epoch: [8]  [ 70/159]  eta: 0:00:56  lr: 0.000050  loss: 0.0911 (0.1381)  loss_classifier: 0.0709 (0.1143)  loss_box_reg: 0.0149 (0.0229)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.6322  data: 0.0108  max mem: 6206
# Epoch: [8]  [ 80/159]  eta: 0:00:50  lr: 0.000050  loss: 0.1728 (0.1424)  loss_classifier: 0.1427 (0.1177)  loss_box_reg: 0.0197 (0.0237)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.6456  data: 0.0109  max mem: 6206
# Epoch: [8]  [ 90/159]  eta: 0:00:43  lr: 0.000050  loss: 0.0969 (0.1365)  loss_classifier: 0.0762 (0.1128)  loss_box_reg: 0.0176 (0.0227)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.6172  data: 0.0106  max mem: 6206
# Epoch: [8]  [100/159]  eta: 0:00:36  lr: 0.000050  loss: 0.0823 (0.1356)  loss_classifier: 0.0697 (0.1119)  loss_box_reg: 0.0156 (0.0228)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0003 (0.0006)  time: 0.5770  data: 0.0096  max mem: 6206
# Epoch: [8]  [110/159]  eta: 0:00:30  lr: 0.000050  loss: 0.0843 (0.1336)  loss_classifier: 0.0735 (0.1102)  loss_box_reg: 0.0195 (0.0225)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 0.5630  data: 0.0101  max mem: 6206
# Epoch: [8]  [120/159]  eta: 0:00:24  lr: 0.000050  loss: 0.0843 (0.1338)  loss_classifier: 0.0686 (0.1105)  loss_box_reg: 0.0195 (0.0224)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0008 (0.0006)  time: 0.5705  data: 0.0095  max mem: 6206
# Epoch: [8]  [130/159]  eta: 0:00:17  lr: 0.000050  loss: 0.1244 (0.1323)  loss_classifier: 0.1014 (0.1093)  loss_box_reg: 0.0151 (0.0221)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0007 (0.0006)  time: 0.6002  data: 0.0100  max mem: 6206
# Epoch: [8]  [140/159]  eta: 0:00:11  lr: 0.000050  loss: 0.0853 (0.1324)  loss_classifier: 0.0686 (0.1089)  loss_box_reg: 0.0176 (0.0225)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0006)  time: 0.5853  data: 0.0095  max mem: 6206
# Epoch: [8]  [150/159]  eta: 0:00:05  lr: 0.000050  loss: 0.1066 (0.1344)  loss_classifier: 0.0883 (0.1103)  loss_box_reg: 0.0259 (0.0231)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.5758  data: 0.0105  max mem: 6206
# Epoch: [8]  [158/159]  eta: 0:00:00  lr: 0.000050  loss: 0.1131 (0.1322)  loss_classifier: 0.0951 (0.1085)  loss_box_reg: 0.0179 (0.0227)  loss_objectness: 0.0000 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.5904  data: 0.0104  max mem: 6206
# Epoch: [8] Total time: 0:01:37 (0.6106 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:11  model_time: 0.1591 (0.1591)  evaluator_time: 0.0030 (0.0030)  time: 0.2765  data: 0.1125  max mem: 6206
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1115 (0.1155)  evaluator_time: 0.0024 (0.0026)  time: 0.1251  data: 0.0072  max mem: 6206
# Test: Total time: 0:00:05 (0.1318 s / it)
# Averaged stats: model_time: 0.1115 (0.1155)  evaluator_time: 0.0024 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [9]  [  0/159]  eta: 0:01:45  lr: 0.000005  loss: 0.1455 (0.1455)  loss_classifier: 0.1107 (0.1107)  loss_box_reg: 0.0336 (0.0336)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0010 (0.0010)  time: 0.6604  data: 0.1372  max mem: 6206
# Epoch: [9]  [ 10/159]  eta: 0:01:32  lr: 0.000005  loss: 0.1822 (0.2026)  loss_classifier: 0.1454 (0.1711)  loss_box_reg: 0.0336 (0.0307)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.6181  data: 0.0212  max mem: 6206
# Epoch: [9]  [ 20/159]  eta: 0:01:24  lr: 0.000005  loss: 0.1323 (0.1619)  loss_classifier: 0.1201 (0.1371)  loss_box_reg: 0.0162 (0.0240)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 0.6021  data: 0.0107  max mem: 6206
# Epoch: [9]  [ 30/159]  eta: 0:01:15  lr: 0.000005  loss: 0.1028 (0.1482)  loss_classifier: 0.0851 (0.1236)  loss_box_reg: 0.0146 (0.0234)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 0.5727  data: 0.0099  max mem: 6206
# Epoch: [9]  [ 40/159]  eta: 0:01:10  lr: 0.000005  loss: 0.1028 (0.1391)  loss_classifier: 0.0754 (0.1154)  loss_box_reg: 0.0198 (0.0226)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 0.5876  data: 0.0089  max mem: 6206
# Epoch: [9]  [ 50/159]  eta: 0:01:04  lr: 0.000005  loss: 0.0968 (0.1355)  loss_classifier: 0.0748 (0.1127)  loss_box_reg: 0.0191 (0.0217)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 0.6063  data: 0.0102  max mem: 6206
# Epoch: [9]  [ 60/159]  eta: 0:00:58  lr: 0.000005  loss: 0.0989 (0.1393)  loss_classifier: 0.0791 (0.1163)  loss_box_reg: 0.0150 (0.0220)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0003 (0.0005)  time: 0.5939  data: 0.0094  max mem: 6206
# Epoch: [9]  [ 70/159]  eta: 0:00:52  lr: 0.000005  loss: 0.0922 (0.1315)  loss_classifier: 0.0710 (0.1099)  loss_box_reg: 0.0120 (0.0205)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0003 (0.0005)  time: 0.5934  data: 0.0094  max mem: 6206
# Epoch: [9]  [ 80/159]  eta: 0:00:47  lr: 0.000005  loss: 0.0922 (0.1339)  loss_classifier: 0.0710 (0.1111)  loss_box_reg: 0.0122 (0.0217)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 0.6368  data: 0.0098  max mem: 6206
# Epoch: [9]  [ 90/159]  eta: 0:00:41  lr: 0.000005  loss: 0.1634 (0.1378)  loss_classifier: 0.1275 (0.1144)  loss_box_reg: 0.0233 (0.0223)  loss_objectness: 0.0000 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0006)  time: 0.6366  data: 0.0102  max mem: 6206
# Epoch: [9]  [100/159]  eta: 0:00:35  lr: 0.000005  loss: 0.1487 (0.1368)  loss_classifier: 0.1259 (0.1130)  loss_box_reg: 0.0215 (0.0227)  loss_objectness: 0.0000 (0.0005)  loss_rpn_box_reg: 0.0007 (0.0006)  time: 0.5877  data: 0.0098  max mem: 6206
# Epoch: [9]  [110/159]  eta: 0:00:29  lr: 0.000005  loss: 0.0853 (0.1348)  loss_classifier: 0.0800 (0.1112)  loss_box_reg: 0.0163 (0.0225)  loss_objectness: 0.0000 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0006)  time: 0.6001  data: 0.0086  max mem: 6206
# Epoch: [9]  [120/159]  eta: 0:00:23  lr: 0.000005  loss: 0.0911 (0.1318)  loss_classifier: 0.0800 (0.1088)  loss_box_reg: 0.0147 (0.0219)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0003 (0.0006)  time: 0.6616  data: 0.0109  max mem: 6206
# Epoch: [9]  [130/159]  eta: 0:00:17  lr: 0.000005  loss: 0.0844 (0.1300)  loss_classifier: 0.0721 (0.1070)  loss_box_reg: 0.0147 (0.0220)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0003 (0.0006)  time: 0.6344  data: 0.0129  max mem: 6206
# Epoch: [9]  [140/159]  eta: 0:00:11  lr: 0.000005  loss: 0.1162 (0.1324)  loss_classifier: 0.0909 (0.1088)  loss_box_reg: 0.0241 (0.0225)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 0.5764  data: 0.0107  max mem: 6206
# Epoch: [9]  [150/159]  eta: 0:00:05  lr: 0.000005  loss: 0.1410 (0.1319)  loss_classifier: 0.1074 (0.1084)  loss_box_reg: 0.0247 (0.0225)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 0.6070  data: 0.0115  max mem: 6206
# Epoch: [9]  [158/159]  eta: 0:00:00  lr: 0.000005  loss: 0.1003 (0.1330)  loss_classifier: 0.0840 (0.1091)  loss_box_reg: 0.0166 (0.0228)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0008 (0.0007)  time: 0.6029  data: 0.0111  max mem: 6206
# Epoch: [9] Total time: 0:01:36 (0.6079 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:10  model_time: 0.1658 (0.1658)  evaluator_time: 0.0028 (0.0028)  time: 0.2712  data: 0.1006  max mem: 6206
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1117 (0.1154)  evaluator_time: 0.0024 (0.0025)  time: 0.1258  data: 0.0077  max mem: 6206
# Test: Total time: 0:00:05 (0.1304 s / it)
# Averaged stats: model_time: 0.1117 (0.1154)  evaluator_time: 0.0024 (0.0025)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
